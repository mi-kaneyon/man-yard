# %% [markdown]
# # お絵描き学習 Drawing

# %%
from PyQt5.QtWidgets import QApplication, QGraphicsView, QGraphicsScene, QMainWindow, QPushButton, QVBoxLayout, QWidget, QLabel, QHBoxLayout
from PyQt5.QtCore import Qt, QRectF, QPointF, QTimer
from PyQt5.QtGui import QPainter, QColor, QPen, QPolygonF
import sys
import random
import math

class DrawingApp(QMainWindow):
    def __init__(self):
        super().__init__()
        self.initUI()
        self.last_point = None

    def initUI(self):
        self.setWindowTitle('Line DRAW')
        self.setGeometry(100, 100, 800, 600)

        self.example_view = QGraphicsView()
        self.example_scene = QGraphicsScene()
        self.example_view.setScene(self.example_scene)
        self.example_view.setRenderHint(QPainter.Antialiasing)
        self.example_view.setSceneRect(QRectF(0, 0, 400, 400))
        self.example_view.setFixedSize(400, 400)

        self.user_view = QGraphicsView()
        self.user_scene = QGraphicsScene()
        self.user_view.setScene(self.user_scene)
        self.user_view.setRenderHint(QPainter.Antialiasing)
        self.user_view.setSceneRect(QRectF(0, 0, 400, 400))
        self.user_view.setFixedSize(400, 400)
        self.user_view.setInteractive(True)
        self.user_view.mousePressEvent = self.draw_point
        self.user_view.mouseMoveEvent = self.draw_line

        self.compare_btn = QPushButton('COMPARE', self)
        self.compare_btn.clicked.connect(self.compare_drawings)
        
        self.restart_btn = QPushButton('RESTART', self)
        self.restart_btn.clicked.connect(self.restart_app)

        self.exit_btn = QPushButton('EXIT', self)
        self.exit_btn.clicked.connect(self.close)

        self.result_label = QLabel("Result will be displayed here", self)

        btn_layout = QHBoxLayout()
        btn_layout.addWidget(self.compare_btn)
        btn_layout.addWidget(self.restart_btn)

        layout = QVBoxLayout()
        layout.addWidget(self.example_view)
        layout.addWidget(self.user_view)
        layout.addLayout(btn_layout)
        layout.addWidget(self.result_label)
        layout.addWidget(self.exit_btn)

        container = QWidget()
        container.setLayout(layout)

        self.setCentralWidget(container)
        self.show()

        self.draw_example_shapes()
        self.draw_dots(self.example_scene)
        self.draw_dots(self.user_scene)

    def draw_dots(self, scene):
        pen = QPen(QColor(0, 0, 0))
        pen.setWidth(2)
        for i in range(0, 401, 50):
            for j in range(0, 401, 50):
                scene.addEllipse(i, j, 2, 2, pen)

    def draw_point(self, event):
        pen = QPen(QColor(255, 0, 0))
        pen.setWidth(2)
        point = event.pos()
        self.user_scene.addEllipse(point.x(), point.y(), 2, 2, pen)
        self.last_point = point

    def draw_line(self, event):
        if self.last_point:
            pen = QPen(QColor(255, 0, 0))
            pen.setWidth(2)
            new_point = event.pos()
            self.user_scene.addLine(self.last_point.x(), self.last_point.y(), new_point.x(), new_point.y(), pen)
            self.last_point = new_point

    def draw_example_shapes(self):
        pen = QPen(QColor(0, 0, 255))
        pen.setWidth(2)
        grid_points = [(i, j) for i in range(0, 401, 50) for j in range(0, 401, 50)]
        for _ in range(2):
            points = random.sample(grid_points, random.randint(3, 5))
            self.example_scene.addPolygon(QPolygonF([QPointF(x, y) for x, y in points]), pen)

    def compare_drawings(self):
        # Dummy logic for now
        result = "WIN!"
        self.result_label.setText(result)
        self.result_label.setStyleSheet('color: red')

    def restart_app(self):
        self.example_scene.clear()
        self.user_scene.clear()
        self.draw_example_shapes()
        self.draw_dots(self.example_scene)
        self.draw_dots(self.user_scene)
        self.result_label.setText("Result will be displayed here")
        self.result_label.setStyleSheet('color: black')

if __name__ == '__main__':
    app = QApplication([])
    ex = DrawingApp()
    sys.exit(app.exec_())
# Out:
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/lib/x86_64-linux-gnu" ...
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/crt1.o"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/crt1.o'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/crti.o"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/crti.o'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/crtn.o"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/crtn.o'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/cups-pk-helper-mechanism"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/cups-pk-helper-mechanism'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/gcrt1.o"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/gcrt1.o'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/grcrt1.o"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/grcrt1.o'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/liba52-0.7.4.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/liba52-0.7.4.so'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libaa.so.1"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libaa.so.1.0.4'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libaa.so.1.0.4"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libaa.so.1.0.4'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libaacs.so.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libaacs.so.0.7.2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libaacs.so.0.7.2"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libaacs.so.0.7.2'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_any_cast_impl.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_optional_access.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_bad_variant_access.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_base.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_base.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_base.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_base.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_base.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_base.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_base.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_base.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_base.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_city.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_city.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_city.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_city.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_city.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_city.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_city.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_city.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_city.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_civil_time.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_civil_time.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_civil_time.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_civil_time.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_civil_time.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_civil_time.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_civil_time.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_civil_time.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_civil_time.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_cord.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_cord.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_cord.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_cord.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_cord.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_cord.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_cord.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_cord.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_cord.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_debugging_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_demangle_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_examine_stack.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_exponential_biased.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_failure_signal_handler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_commandlineflag_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_config.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_config.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_config.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_config.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_config.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_config.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_config.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_config.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_config.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_marshalling.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_parse.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_private_handle_accessor.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_program_name.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_reflection.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_flags_usage_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_graphcycles_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hash.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_hash.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_hash.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hash.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_hash.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hash.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_hash.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hash.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_hash.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_hashtablez_sampler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_int128.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_int128.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_int128.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_int128.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_int128.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_int128.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_int128.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_int128.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_int128.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_leak_check.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_leak_check.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_leak_check.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_leak_check.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_leak_check.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_leak_check_disable.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_log_severity.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_log_severity.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_log_severity.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_log_severity.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_log_severity.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_log_severity.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_log_severity.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_log_severity.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_log_severity.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_malloc_internal.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_periodic_sampler.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_distributions.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_distribution_test_util.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_platform.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_pool_urbg.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_hwaes_impl.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_randen_slow.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_internal_seed_material.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_gen_exception.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_random_seed_sequences.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.a' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.so"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.so.20210324"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.so.20210324.0.0"
# "Failed to extract plugin meta data from '/usr/lib/x86_64-linux-gnu/libabsl_raw_hash_set.so.20210324.0.0'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/usr/lib/x86_64-linux-gnu/libabsl_raw_logging_internal.a"
# QElfParser: '/usr/lib/x86_64-linux-gnu/libabsl_raw_logging_internal.a' is not an ELF object
# "'/usr/lib/x86_64-linux-gnu/libabsl_raw_logging_internal.a' is not an ELF object"
#          not a plugin
# ...
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/watchmedo"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/watchmedo' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/watchmedo' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/webpinfo"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/webpinfo'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/webpmux"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/webpmux'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/wheel"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/wheel' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/wheel' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/wish"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/wish8.6'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/wish8.6"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/wish8.6'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/wrjpgcom"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/wrjpgcom'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/wsdump"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/wsdump' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/wsdump' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/x264"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/x264'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/x86_64-conda-linux-gnu-ld"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/x86_64-conda-linux-gnu-ld'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/x86_64-conda_cos7-linux-gnu-ld"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/x86_64-conda-linux-gnu-ld'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xkbcli"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xkbcli'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xml2-config"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xml2-config' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xml2-config' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xml2-config.bak"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xml2-config.bak' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xml2-config.bak' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xmlcatalog"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xmlcatalog'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xmllint"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xmllint'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xmlpatterns"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xmlpatterns'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xmlpatternsvalidator"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xmlpatternsvalidator'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xmlwf"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xmlwf'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xslt-config"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xslt-config' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xslt-config' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xsltproc"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xsltproc'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xz"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xz'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzcat"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xz'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzcmp"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xzdiff' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xzdiff' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzdec"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/xzdec'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzdiff"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xzdiff' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xzdiff' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzegrep"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xzgrep' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xzgrep' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzfgrep"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xzgrep' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xzgrep' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzgrep"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xzgrep' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xzgrep' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzless"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xzless' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xzless' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/xzmore"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/xzmore' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/xzmore' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/yapf"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/yapf' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/yapf' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/yapf-diff"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/yapf-diff' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/yapf-diff' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/zstd"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/zstd'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/zstdcat"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/zstd'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/zstdgrep"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/zstdgrep' is not an ELF object
# "'/home/kanengi/anaconda3/envs/isac/bin/zstdgrep' is not an ELF object"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/zstdless"
# QElfParser: '/home/kanengi/anaconda3/envs/isac/bin/zstdless' is not an ELF object (file too small)
# "'/home/kanengi/anaconda3/envs/isac/bin/zstdless' is not an ELF object (file too small)"
#          not a plugin
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/bin/zstdmt"
# "Failed to extract plugin meta data from '/home/kanengi/anaconda3/envs/isac/bin/zstd'"
#          not a plugin
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/lib/x86_64-linux-gnu/platformthemes" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platformthemes" ...
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platformthemes/libqgtk3.so"
# Found metadata in lib /home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platformthemes/libqgtk3.so, metadata=
# {
#     "IID": "org.qt-project.Qt.QPA.QPlatformThemeFactoryInterface.5.1",
#     "MetaData": {
#         "Keys": [
#             "gtk3"
#         ]
#     },
#     "archreq": 0,
#     "className": "QGtk3ThemePlugin",
#     "debug": false,
#     "version": 331520
# }
#
#
# Got keys from plugin meta data ("gtk3")
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platformthemes/libqxdgdesktopportal.so"
# Found metadata in lib /home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platformthemes/libqxdgdesktopportal.so, metadata=
# {
#     "IID": "org.qt-project.Qt.QPA.QPlatformThemeFactoryInterface.5.1",
#     "MetaData": {
#         "Keys": [
#             "xdgdesktopportal",
#             "flatpak",
#             "snap"
#         ]
#     },
#     "archreq": 0,
#     "className": "QXdgDesktopPortalThemePlugin",
#     "debug": false,
#     "version": 331520
# }
#
#
# Got keys from plugin meta data ("xdgdesktopportal", "flatpak", "snap")
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/bin/platformthemes" ...
# loaded library "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platformthemes/libqgtk3.so"
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/lib/x86_64-linux-gnu/platforminputcontexts" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platforminputcontexts" ...
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platforminputcontexts/libcomposeplatforminputcontextplugin.so"
# Found metadata in lib /home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platforminputcontexts/libcomposeplatforminputcontextplugin.so, metadata=
# {
#     "IID": "org.qt-project.Qt.QPlatformInputContextFactoryInterface.5.1",
#     "MetaData": {
#         "Keys": [
#             "compose",
#             "xim"
#         ]
#     },
#     "archreq": 0,
#     "className": "QComposePlatformInputContextPlugin",
#     "debug": false,
#     "version": 331520
# }
#
#
# Got keys from plugin meta data ("compose", "xim")
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platforminputcontexts/libibusplatforminputcontextplugin.so"
# Found metadata in lib /home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platforminputcontexts/libibusplatforminputcontextplugin.so, metadata=
# {
#     "IID": "org.qt-project.Qt.QPlatformInputContextFactoryInterface.5.1",
#     "MetaData": {
#         "Keys": [
#             "ibus"
#         ]
#     },
#     "archreq": 0,
#     "className": "QIbusPlatformInputContextPlugin",
#     "debug": false,
#     "version": 331520
# }
#
#
# Got keys from plugin meta data ("ibus")
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/bin/platforminputcontexts" ...
# loaded library "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/platforminputcontexts/libibusplatforminputcontextplugin.so"
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/lib/x86_64-linux-gnu/styles" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/styles" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/bin/styles" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/lib/x86_64-linux-gnu/xcbglintegrations" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/xcbglintegrations" ...
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/xcbglintegrations/libqxcb-egl-integration.so"
# Found metadata in lib /home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/xcbglintegrations/libqxcb-egl-integration.so, metadata=
# {
#     "IID": "org.qt-project.Qt.QPA.Xcb.QXcbGlIntegrationFactoryInterface.5.5",
#     "MetaData": {
#         "Keys": [
#             "xcb_egl"
#         ]
#     },
#     "archreq": 0,
#     "className": "QXcbEglIntegrationPlugin",
#     "debug": false,
#     "version": 331520
# }
#
#
# Got keys from plugin meta data ("xcb_egl")
# QFactoryLoader::QFactoryLoader() looking at "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/xcbglintegrations/libqxcb-glx-integration.so"
# Found metadata in lib /home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/xcbglintegrations/libqxcb-glx-integration.so, metadata=
# {
#     "IID": "org.qt-project.Qt.QPA.Xcb.QXcbGlIntegrationFactoryInterface.5.5",
#     "MetaData": {
#         "Keys": [
#             "xcb_glx"
#         ]
#     },
#     "archreq": 0,
#     "className": "QXcbGlxIntegrationPlugin",
#     "debug": false,
#     "version": 331520
# }
#
#
# Got keys from plugin meta data ("xcb_glx")
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/bin/xcbglintegrations" ...
# loaded library "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/xcbglintegrations/libqxcb-glx-integration.so"
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/lib/x86_64-linux-gnu/accessible" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/accessible" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/bin/accessible" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/usr/lib/x86_64-linux-gnu/accessiblebridge" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/PyQt5/Qt5/plugins/accessiblebridge" ...
# QFactoryLoader::QFactoryLoader() checking directory path "/home/kanengi/anaconda3/envs/isac/bin/accessiblebridge" ...
# Comparing drawings...
# WIN!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/kanengi/anaconda3/envs/isac/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3406: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
